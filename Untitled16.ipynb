# %% [markdown]
# <a href="https://colab.research.google.com/github/Jessee-M/dsc-running-jupyter-locally-lab/blob/master/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
store = pd.read_csv('/content/Stores.csv')
store
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0            1        1659             1961                   530        66490
# 1            2        1461             1752                   210        39820
# 2            3        1340             1609                   720        54010
# 3            4        1451             1748                   620        53730
# 4            5        1770             2111                   450        46620
# ..         ...         ...              ...                   ...          ...
# 891        892        1582             1910                  1080        66390
# 892        893        1387             1663                   850        82080
# 893        894        1200             1436                  1060        76440
# 894        895        1299             1560                   770        96610
# 895        896        1174             1429                  1110        54340
#
# [896 rows x 5 columns]

# %%
store_area = list(store['Store_Area'])
store_ID = list(store['Store ID '])
items_available = list(store['Items_Available'])
daily_customer_count = list(store['Daily_Customer_Count'])
store_sales = list(store['Store_Sales'])

# %%
number_of_sales = len(store_sales)
number_of_sales
# Out:
# 896

# %%
max_sales = max(store_sales)
max_sales
# Out:
# 116320

# %%
min_sales = min(store_sales)
min_sales
# Out:
# 14920

# %%
average_sales = sum(store_sales)/number_of_sales
print(int(average_sales))
# Out:
# 59351

# %%
import numpy as np

# %%
average = np.mean(store_sales)
average
# Out:
# np.float64(59351.30580357143)

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(store_sales, edgecolor = 'black')
# Out:
# (array([ 13.,  45., 146., 188., 173., 157., 116.,  44.,  13.,   1.]),
#  array([ 14920.,  25060.,  35200.,  45340.,  55480.,  65620.,  75760.,
#          85900.,  96040., 106180., 116320.]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(store_sales)
plt.title('Box plot showing Store Sales')
plt.ylabel('Store Sales')
# Out:
# Text(0, 0.5, 'Store Sales')

# %%
np.median(store_sales)
# Out:
# np.float64(58605.0)

# %%
variance = np.var(store_sales)
variance
# Out:
# np.float64(295191783.6743413)

# %%
store_area_sales = np.corrcoef(store_area,store_sales)

# %%
(store_area_sales[0][1])*100
# Out:
# np.float64(9.747379539480509)

# %%
plt.scatter(store_area,store_sales)
plt.title('Correlation of Sales and Store Area')
np.polyfit(store_area,store_sales,0)
plt.legend()
plt.xlabel('Store Area')
plt.ylabel('Store Sales')
# Out:
# Text(0, 0.5, 'Store Sales')

# %%
np.corrcoef(store_sales,daily_customer_count)
# Out:
# array([[1.        , 0.00862871],
#        [0.00862871, 1.        ]])

# %%
plt.scatter(store_sales,daily_customer_count)
plt.title('Correlation of Sales with Customer Count')
plt.ylabel('Daily Customer Count')
plt.xlabel('Store Sales')
# Out:
# Text(0.5, 0, 'Store Sales')
